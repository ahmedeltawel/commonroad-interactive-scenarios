# %% [markdown]
# # Tutorial: SUMO Manager
# ## 1. Introduction to SUMO manager.
# The [SUMO-manager](https://gitlab.lrz.de/cps/commonroad-sumo-manager/-/tree/development) is a module contains a complete CommonRoad-SUMO interface. The SUMO simulator is executed in a Docker container, which is started automatically by the interface. The aim of the SUMO-manager is to help the user convert, generate or simulate a scenario without installing so many external repositories.
#
# The module is still under development, if you encounter any issue or you have some feature requests, feel free to contact us! :)

# %% [markdown]
# ## 2. Utilize SUMO manager in scenario conversion.
#
# The functionality of converting scenario using SUMO-manager is not yet implemented in this repository. So we need to import the function **convert_scenario** from SUMO-manager.

# %%
import sys
sys.path.append("..")
from configuration.config_1 import SumoConfig_1
from example.convert_scenario import convert_scenario
import pickle
import os

scenario_name = "DEU_A9-2_1_T-1"
input_scenario_folder = "../example_scenarios/cr_scenario"
output_scenario_folder = "../example_scenarios/output/tutorial_4"

convert_scenario(scenario_name  = scenario_name,
                input_scenario_folder = input_scenario_folder,
                output_scenario_folder = output_scenario_folder)


conf = SumoConfig_1.from_scenario_name(scenario_name)
conf.scenario_name = scenario_name
with open(os.path.join(output_scenario_folder, scenario_name, "simulation_config.p"), 'wb') as f:
    pickle.dump(conf, f)
# Out:
# INFO:crsumo.docker_runner:Image gitlab.lrz.de:5005/cps/commonroad-sumo-manager:ver0.7.0 found
# Converting DEU_A9-2_1_T-1
# DEBUG:crsumo.docker_runner:Starting Docker logger
# INFO:crsumo.docker_runner:Container started with ID: dd6c944cfb2f8418b6d87f675f3bf55e860f0b82378fe498bfcc79e111aaa96d
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T20:59:39.073753591Z INFO:sumo_manager_server.sumo_interface:SumoSimulation server started, listening on port 50051
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T20:59:40.193645724Z Additional file written to /scenarios/DEU_A9-2_1_T-1/DEU_A9-2_1_T-1.add.xml
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T20:59:40.193972379Z SUMO traffic generation: traffic frequency is defined based on the total lane length of the road network.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T20:59:40.359212178Z INFO:sumo_manager_server.sumo_interface:SumoSimulation server terminated
# DEBUG:crsumo.docker_runner:Docker logger ended
# DEBUG:crsumo.docker_runner:Stopping Docker logger
# DEBUG:crsumo.docker_runner:Docker logger stopped
# INFO:crsumo.docker_runner:Container dd6c944cfb2f8418b6d87f675f3bf55e860f0b82378fe498bfcc79e111aaa96d stopped
# DEBUG:crsumo.docker_runner:Stopping Docker logger
# DEBUG:crsumo.docker_runner:Docker logger stopped
# Conversion DEU_A9-2_1_T-1 ended

# %% [markdown]
# ## 3. Utilize SUMO manager in scenario simulation.
#
# The utilization of SUMO-manager in simulating a scenario is easier as it is already integrated in the interactive benchmark. You can call that by switching the argument **use_sumo_manager** of the function **simulate_interactive_solution** to True.

# %%
from evaluation.simulate_solution import simulate_interactive_solution

interactive_scenario_folder = "../example_scenarios/output/tutorial_4/DEU_A9-2_1_T-1"
solution_file = "../example_scenarios/solution/KS1:SA1:DEU_A9-2_1_T-1:2018b.xml"
output_folder_path = "../example_scenarios/gif/sumo_manager"
creating_video = True 
use_sumo_manager = True

without_ego, with_ego = simulate_interactive_solution(interactive_scenario_folder = interactive_scenario_folder,
                              solution_file = solution_file,
                              output_folder_path = output_folder_path,
                              creating_video = creating_video,
                              use_sumo_manager = use_sumo_manager)
# Out:
# INFO:crsumo.docker_runner:Image gitlab.lrz.de:5005/cps/commonroad-sumo-manager:ver0.7.0 found
# DEBUG:crsumo.docker_runner:Starting Docker logger
# INFO:crsumo.docker_runner:Container started with ID: ee41c7e18e7ac58433b1346c8c654975348760aeeb1a9f6b21578226589bd8df
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:02.440346565Z INFO:sumo_manager_server.sumo_interface:SumoSimulation server started, listening on port 50051
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:03.747825223Z  Retrying in 1 seconds
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:03.794286701Z Loading configuration ... done.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:03.799122472Z ***Starting server on port 35445 ***
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:04.752475547Z Loading net-file from 'scenarios/DEU_A9-2_1_T-1/DEU_A9-2_1_T-1.net.xml' ... done (0ms).
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:04.753825571Z Loading additional-files from 'scenarios/DEU_A9-2_1_T-1/DEU_A9-2_1_T-1.add.xml' ... done (0ms).
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:04.754383267Z Loading done.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:04.762471526Z Simulation version v1_2_0+5214-53edc58fcd started with time: 0.00
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:04.768065793Z WARNING:SumoSimulationSession:No ego vehicles entered simulation.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:04.792583918Z WARNING:SumoSimulationSession:No ego vehicles entered simulation.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022679672Z Simulation ended at time: 1.30
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022716043Z Reason: TraCI requested termination.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022722661Z Performance:
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022725470Z  Duration: 269ms
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022728003Z  Real time factor: 4.83271
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022730338Z  UPS: 275.092937
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022732582Z Vehicles:
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022734789Z  Inserted: 9 (Loaded: 270)
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022737028Z  Running: 9
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022739153Z  Waiting: 3
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.022741334Z
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:05.041203060Z INFO:sumo_manager_server.sumo_interface:SumoSimulation server terminated
# DEBUG:crsumo.docker_runner:Docker logger ended
# WARNING:crsumo.docker_runner:No such container: ee41c7e18e7ac58433b1346c8c654975348760aeeb1a9f6b21578226589bd8df
# DEBUG:crsumo.docker_runner:Stopping Docker logger
# DEBUG:crsumo.docker_runner:Docker logger stopped
# INFO:crsumo.docker_runner:Container ee41c7e18e7ac58433b1346c8c654975348760aeeb1a9f6b21578226589bd8df stopped
# DEBUG:crsumo.docker_runner:Stopping Docker logger
# DEBUG:crsumo.docker_runner:Docker logger stopped
# INFO:crsumo.docker_runner:Image gitlab.lrz.de:5005/cps/commonroad-sumo-manager:ver0.7.0 found
# DEBUG:crsumo.docker_runner:Starting Docker logger
# INFO:crsumo.docker_runner:Container started with ID: d24c558b5b954240aa75e0a4c89f2715d9716e243c3e46017bac9922ba476e75
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:07.699558222Z INFO:sumo_manager_server.sumo_interface:SumoSimulation server started, listening on port 50051
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:09.390031949Z  Retrying in 1 seconds
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:09.410451118Z Loading configuration ... done.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:09.415973266Z ***Starting server on port 52839 ***
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:10.393739822Z Loading net-file from 'scenarios/DEU_A9-2_1_T-1/DEU_A9-2_1_T-1.net.xml' ... done (0ms).
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:10.394402533Z Loading additional-files from 'scenarios/DEU_A9-2_1_T-1/DEU_A9-2_1_T-1.add.xml' ... done (1ms).
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:10.394790652Z Loading done.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:10.403209812Z Simulation version v1_2_0+5214-53edc58fcd started with time: 0.00
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:10.407126521Z WARNING:SumoSimulationSession:No ego vehicles entered simulation.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:10.431939002Z WARNING:SumoSimulationSession:No ego vehicles entered simulation.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890711871Z Simulation ended at time: 20.30
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890740709Z Reason: TraCI requested termination.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890745535Z Performance:
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890748561Z  Duration: 3497ms
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890751301Z  Real time factor: 5.80498
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890753965Z  UPS: 1293.966257
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890756561Z Vehicles:
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890759725Z  Inserted: 35 (Loaded: 270)
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890762363Z  Running: 25
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890764936Z  Waiting: 148
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.890767447Z
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:00:13.909455937Z INFO:sumo_manager_server.sumo_interface:SumoSimulation server terminated
# DEBUG:crsumo.docker_runner:Docker logger ended
# WARNING:crsumo.docker_runner:No such container: d24c558b5b954240aa75e0a4c89f2715d9716e243c3e46017bac9922ba476e75
# DEBUG:crsumo.docker_runner:Stopping Docker logger
# DEBUG:crsumo.docker_runner:Docker logger stopped
# INFO:crsumo.docker_runner:Container d24c558b5b954240aa75e0a4c89f2715d9716e243c3e46017bac9922ba476e75 stopped
# DEBUG:crsumo.docker_runner:Stopping Docker logger
# DEBUG:crsumo.docker_runner:Docker logger stopped
# Saving DEU_A9-2_1_T-1.gif
# DEU_A9-2_1_T-1.gif saved

# %% [markdown]
# ## 4. Utilize SUMO manager in determinism check.
#
# Similar to that in simulation, in checking the determinism of a scenario, the SUMO-manager can also be used by setting the argument **use_sumo_manager** to True. Actually, the SUMO-manager here only helps with resimulating the scenario.

# %%
from determinism_checker.route_file_checker import rou_file_determinism_check
from determinism_checker.simulation_checker import resimulate_scenario, plot_vehicle_trajectories, \
    obstacle_determinism_check
from determinism_checker.check_determinism import check_determinism

scenario_file_path = "../example_scenarios/output/tutorial_4/DEU_A9-2_1_T-1"
num_of_simulations = 5
output_folder_path = "../example_scenarios/gif/sumo_manager"
use_sumo_manager = True
creating_video = False

check_determinism(scenario_file_path = scenario_file_path,
                  num_of_simulations = num_of_simulations,
                  output_folder_path = output_folder_path,
                  use_sumo_manager = use_sumo_manager,
                  creating_video = creating_video)
# Out:
# INFO:crsumo.docker_runner:Image gitlab.lrz.de:5005/cps/commonroad-sumo-manager:ver0.7.0 found
# Simulation 0 start.
# DEBUG:crsumo.docker_runner:Starting Docker logger
# INFO:crsumo.docker_runner:Container started with ID: 88274f6fa7d726ded51e5fb4baea26a0f2899d1e554fcb893f763a2a7253d6d6
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:17.168355140Z INFO:sumo_manager_server.sumo_interface:SumoSimulation server started, listening on port 50051
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:18.619539228Z  Retrying in 1 seconds
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:18.699462990Z Loading configuration ... done.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:18.707936276Z ***Starting server on port 37701 ***
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:19.625016369Z Loading net-file from 'scenarios/DEU_A9-2_1_T-1/DEU_A9-2_1_T-1.net.xml' ... done (1ms).
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:19.627337409Z Loading additional-files from 'scenarios/DEU_A9-2_1_T-1/DEU_A9-2_1_T-1.add.xml' ... done (1ms).
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:19.627953696Z Loading done.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:19.644834664Z Simulation version v1_2_0+5214-53edc58fcd started with time: 0.00
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:19.648035791Z WARNING:SumoSimulationSession:No ego vehicles entered simulation.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233020013Z Simulation ended at time: 20.20
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233045612Z Reason: TraCI requested termination.
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233049700Z Performance:
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233052380Z  Duration: 2606ms
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233054818Z  Real time factor: 7.75134
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233058260Z  UPS: 1351.880276
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233060650Z Vehicles:
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233062970Z  Inserted: 29 (Loaded: 269)
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233065370Z  Running: 21
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233067731Z  Waiting: 152
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.233069986Z
# INFO:crsumo.docker_runner:DockerMsg: 2020-12-11T21:01:22.262645605Z INFO:sumo_manager_server.sumo_interface:SumoSimulation server terminated
# DEBUG:crsumo.docker_runner:Docker logger ended
# WARNING:crsumo.docker_runner:No such container: 88274f6fa7d726ded51e5fb4baea26a0f2899d1e554fcb893f763a2a7253d6d6
# DEBUG:crsumo.docker_runner:Stopping Docker logger
# DEBUG:crsumo.docker_runner:Docker logger stopped
# INFO:crsumo.docker_runner:Container 88274f6fa7d726ded51e5fb4baea26a0f2899d1e554fcb893f763a2a7253d6d6 stopped
# DEBUG:crsumo.docker_runner:Stopping Docker logger
# DEBUG:crsumo.docker_runner:Docker logger stopped
# Checking the route files
# The rou files are deterministic
# Checking the obstacles' trajectories
# The vehicles are deterministic.
# The scenario is deterministic.
# True
